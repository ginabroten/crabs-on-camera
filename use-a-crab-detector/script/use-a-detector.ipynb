# %%
## Go from unseen material to assessment ready data
## Use the added model, or add your own
## Independent testset to check generalizability go from 
## Predict on unseen footage
## Interpret raw prediction behavior + collect raw MaxN
## Apply post-processing filters/confidence thresholding
## Collect assessmentready data

# %%
# ------------------- CONFIG ------------------- #
MODEL_PATH = "/scratch/disk4/crab_model_gina/final_model/results/final_model_100ep_960/weights/best.pt"

INPUT_FOLDER = "/scratch/disk4/crab_model_gina/BRUV2024/BRUV_test_stations"
OUTPUT_FOLDER = "/scratch/disk4/crab_model_gina/BRUV2024/BRUV_test_output"  # <-- you choose this
TARGET_FPS = 1  # run YOLO at 1 FPS
# ------------------------------------------------ #
